# %% [markdown]
# # Line plot

# %%
import matplotlib.pyplot as plt
plt.plot([1,2,3,4])
plt.ylabel('some numberr')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot([1,2,3,4], [1,4,9,16])

# %%
plt.plot([1,2,3,4], [1,4,9,16], 'ro')
plt.axis([0,6,0, 20])
plt.show()

# %%
#plots using numpy


import numpy as np
import matplotlib.pyplot as plt

#evenly sampled time at 200ms intervals
t = np.arange(0., 5., 0.2)

#red dashes, blue sq, green triang

plt.plot(t, t, 'r--', t, t**2, 'bs', t,  t**3, 'g')
# Out:
# [<matplotlib.lines.Line2D at 0x2aef322afa0>,
#  <matplotlib.lines.Line2D at 0x2aef322af70>,
#  <matplotlib.lines.Line2D at 0x2aef3238190>]

# %%
def f(t):
    return np.exp(-t) * np.cos(2*np.pi*t)

t1 = np.arange(0., 5., 0.1)

t2 = np.arange(0., 5., 0.02)

plt.figure(1)
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2,f(t2),'k')
# Out:
# [<matplotlib.lines.Line2D at 0x2aef3329940>,
#  <matplotlib.lines.Line2D at 0x2aef3329a00>]

# %%
#bio python


from Bio.Seq import Seq

my_seq = Seq("AGTACACTGGT")

msngr_rna = my_seq.transcribe()
protein1 = my_seq.translate()
protein2 =

# %%
me
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 import Bio
#       2 help(Bio)
#
# ModuleNotFoundError: No module named 'Bio'
